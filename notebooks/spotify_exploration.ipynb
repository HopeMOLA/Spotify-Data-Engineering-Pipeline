# %%
import pandas as pd

df = pd.read_csv("../data/raw/spotify_data.csv")


df.head()
# Out:
#                                                 song        artist  popularity
# 0                                              Shela      Sam Deep          67
# 1                              Lutho (feat. De Rose)    Dj Jaivane          62
# 2  Abantwana Bakho (feat. Thatohatsi, Young Stunn...  DJ Maphorisa          67
# 3                                           Amanxeba      Sami'Kay          67
# 4                                           MAMAZALA      DJ Stoks          35

# %%
df.info()
df.describe()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   song        50 non-null     object
#  1   artist      50 non-null     object
#  2   popularity  50 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 1.3+ KB
# song          0
# artist        0
# popularity    0
# dtype: int64

# %% [markdown]
# ***Clean duplicates***

# %%
df = df.drop_duplicates(subset=["song","artist"])

# %% [markdown]
# ***Clean text***

# %%
df['song'] = df['song'].str.strip()
df['artist'] = df['artist'].str.title()

# %% [markdown]
# ***Convert popularity***

# %%
df['popularity'] = pd.to_numeric(df['popularity'], errors='coerce')

# %% [markdown]
# **Save cleaned dataset**

# %%
df.to_csv("../data/processed/clean_spotify_data.csv", index=False)
